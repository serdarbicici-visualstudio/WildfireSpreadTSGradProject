# %%
#!python3 /content/drive/MyDrive/WildfireSpreadTS-main/src/preprocess/CreateHDF5Dataset.py --data_dir /content/drive/MyDrive/WildfireSpreadTS_data/unzipped --target_dir /content/drive/MyDrive/gradData

# %%
#!pip install -r /content/drive/MyDrive/WildfireSpreadTS-main/requirements.txt
# !pip install pytorch_lightning segmentation_models_pytorch

# %%
# !pip install -U jsonargparse[signatures]>=4.27.7

# %%
import os
os.environ["WANDB_MODE"] = "disabled"
print("WANDB_MODE set to:", os.environ["WANDB_MODE"])
# Out:
# WANDB_MODE set to: disabled

# %%
#!pip install wandb
#!wandb login

# %%
# !python3 /content/drive/MyDrive/WildfireSpreadTS-main/src/train.py --config=/content/drive/MyDrive/WildfireSpreadTS-main/cfgs/unet/res18_monotemporal.yaml --trainer=/content/drive/MyDrive/WildfireSpreadTS-main/cfgs/trainer_single_gpu.yaml --data=/content/drive/MyDrive/WildfireSpreadTS-main/cfgs/data_monotemporal_full_features.yaml --seed_everything=0 --trainer.max_epochs=200 --do_test=True --data.data_dir /content/drive/MyDrive/gradData
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py:1617: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   _C._set_float32_matmul_precision(precision)
# Seed set to 0
# Using the following dataset split:
# Train years: [2018, 2019], Val years: [2020], Test years: [2021]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# wandb: WARNING The anonymous setting has no effect and will be removed in a future version.
# Using the following dataset split:
# ...
